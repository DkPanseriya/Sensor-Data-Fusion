# %%
import torch
from ultralytics import YOLO
import cv2
import time
import json
import numpy as np
import os

# Check if CUDA is available and set the device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load a model
model = YOLO('yolov8l.pt')  # pretrained YOLOv8x model
source = r"C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data"
annotation_path = r"C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Annotation"

# Define a function to calculate the Intersection over Union (IoU) of two bounding boxes
def calculate_iou(box1, box2): 
    x1, y1, x2, y2 = box1 #YOLO
    x1_gt, y1_gt, x2_gt, y2_gt = box2 #Json

    # Calculate the intersection area
    x1_i = max(x1, x1_gt)
    y1_i = max(y1, y1_gt)
    x2_i = min(x2, x2_gt)
    y2_i = min(y2, y2_gt)
    intersection_area = max(0, x2_i - x1_i) * max(0, y2_i - y1_i)

    # Calculate the union area
    box1_area = (x2 - x1) * (y2 - y1)
    box2_area = (x2_gt - x1_gt) * (y2_gt - y1_gt)
    union_area = box1_area + box2_area - intersection_area

    # Calculate the IoU
    iou = intersection_area / union_area  #if union_area != 0 else 1

    return iou

# Initialize a list to store the IoU scores for each result
iou_scores = []

# Get the list of image files
image_files = os.listdir(source)

cv2.namedWindow('scene', cv2.WINDOW_NORMAL)
cv2.resizeWindow('scene',1200, 1200)

# Process each image file
for image_file in image_files:
    # Run inference on the image
    results = model(os.path.join(source, image_file))

    for result in results: #to remove this loop
        boxes = result.boxes  # Boxes object for bounding box outputs

        # Load the ground truth from the corresponding JSON file
        json_file = os.path.join(annotation_path, os.path.splitext(image_file)[0] + '.json')
        with open(json_file) as f:
            ground_truth = json.load(f)

        jason_bboxes = ground_truth['annotations'][0]['bbox']

        # Convert the bounding box to two points
        x1y1 = (int(jason_bboxes[0]), int(jason_bboxes[1]))
        x2y2 = (int(jason_bboxes[0] + jason_bboxes[2]), int(jason_bboxes[1] + jason_bboxes[3]))

        # Convert the image from BGR to RGB
        img_rgb = cv2.cvtColor(result.orig_img, cv2.COLOR_BGR2RGB)


        # Draw bounding boxes on the image
        for box in boxes.xyxy:
            cv2.rectangle(img_rgb, (int(box[0]), int(box[1])), (int(box[2]), int(box[3])), (0, 255, 0), 2)
            cv2.rectangle(img_rgb, (x1y1[0], x1y1[1]) , (x2y2[0], x2y2[1]), (255, 255, 0), 2)

            # For each detected box, calculate the IoU with the ground truth box
            iou = calculate_iou(box, (x1y1[0], x1y1[1] , x2y2[0], x2y2[1]))
            iou_scores.append(iou)

        # Display the image
        cv2.imshow('scene', img_rgb)

        # Wait for 0.5 seconds
        cv2.waitKey(10)

# Close the image window
cv2.destroyAllWindows()

# Calculate the mean IoU score
mean_iou = np.mean(iou_scores)

print(f"The mean IoU score is {mean_iou}")
# Out:
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-51-934.png: 416x640 1 traffic light, 69.1ms
# Speed: 15.6ms preprocess, 69.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-52-034.png: 416x640 1 person, 1 traffic light, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-52-167.png: 416x640 1 person, 1 traffic light, 68.7ms
# Speed: 0.0ms preprocess, 68.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-52-234.png: 416x640 1 traffic light, 65.4ms
# Speed: 0.0ms preprocess, 65.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-52-467.png: 416x640 1 car, 1 traffic light, 64.0ms
# Speed: 0.0ms preprocess, 64.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-52-534.png: 416x640 1 person, 1 traffic light, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-52-634.png: 416x640 1 person, 1 traffic light, 66.8ms
# Speed: 0.0ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-52-767.png: 416x640 1 person, 1 traffic light, 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-52-834.png: 416x640 1 person, 1 traffic light, 64.4ms
# Speed: 0.0ms preprocess, 64.4ms inference, 15.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-52-934.png: 416x640 1 person, 1 car, 1 traffic light, 61.2ms
# Speed: 0.0ms preprocess, 61.2ms inference, 15.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-53-034.png: 416x640 2 persons, 1 car, 1 traffic light, 67.8ms
# Speed: 0.0ms preprocess, 67.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-53-067.png: 416x640 2 persons, 2 cars, 1 traffic light, 63.0ms
# Speed: 0.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-53-134.png: 416x640 3 persons, 2 cars, 1 traffic light, 64.0ms
# Speed: 0.0ms preprocess, 64.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-53-367.png: 416x640 2 persons, 1 traffic light, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-53-634.png: 416x640 2 persons, 1 car, 1 traffic light, 65.1ms
# Speed: 0.0ms preprocess, 65.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-53-667.png: 416x640 2 persons, 1 car, 1 traffic light, 65.6ms
# Speed: 0.0ms preprocess, 65.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-53-734.png: 416x640 2 persons, 1 traffic light, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-53-967.png: 416x640 2 persons, 1 traffic light, 67.4ms
# Speed: 0.0ms preprocess, 67.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-54-234.png: 416x640 2 persons, 1 traffic light, 63.2ms
# Speed: 0.0ms preprocess, 63.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-54-267.png: 416x640 2 persons, 1 traffic light, 51.3ms
# Speed: 15.0ms preprocess, 51.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-54-334.png: 416x640 3 persons, 1 traffic light, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-54-467.png: 416x640 1 person, 1 car, 1 traffic light, 65.9ms
# Speed: 0.0ms preprocess, 65.9ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-54-734.png: 416x640 1 person, 2 cars, 1 traffic light, 67.1ms
# Speed: 0.0ms preprocess, 67.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-54-767.png: 416x640 1 person, 1 car, 1 traffic light, 63.2ms
# Speed: 0.0ms preprocess, 63.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-54-834.png: 416x640 2 persons, 2 cars, 1 traffic light, 78.4ms
# Speed: 0.0ms preprocess, 78.4ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-54-867.png: 416x640 1 person, 2 cars, 1 traffic light, 66.8ms
# Speed: 0.0ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-54-934.png: 416x640 1 person, 2 cars, 1 traffic light, 63.4ms
# Speed: 0.0ms preprocess, 63.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-55-067.png: 416x640 2 persons, 1 car, 1 traffic light, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-55-167.png: 416x640 2 persons, 1 traffic light, 67.0ms
# Speed: 0.0ms preprocess, 67.0ms inference, 0.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-55-367.png: 416x640 3 persons, 1 traffic light, 51.6ms
# Speed: 0.0ms preprocess, 51.6ms inference, 15.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-55-434.png: 416x640 2 persons, 1 traffic light, 64.2ms
# Speed: 0.0ms preprocess, 64.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-55-734.png: 416x640 2 persons, 1 traffic light, 62.4ms
# Speed: 2.5ms preprocess, 62.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-55-934.png: 416x640 2 persons, 1 traffic light, 65.1ms
# Speed: 0.0ms preprocess, 65.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-56-034.png: 416x640 2 persons, 1 car, 1 traffic light, 66.0ms
# Speed: 0.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-56-267.png: 416x640 2 persons, 1 car, 1 traffic light, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-56-534.png: 416x640 1 person, 1 car, 1 traffic light, 67.2ms
# Speed: 0.0ms preprocess, 67.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-56-634.png: 416x640 2 persons, 1 car, 1 traffic light, 64.7ms
# Speed: 0.0ms preprocess, 64.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-56-867.png: 416x640 3 persons, 2 cars, 1 traffic light, 63.6ms
# Speed: 2.0ms preprocess, 63.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-56-934.png: 416x640 3 persons, 1 traffic light, 62.5ms
# Speed: 1.4ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-57-067.png: 416x640 1 person, 3 cars, 1 traffic light, 47.8ms
# Speed: 17.3ms preprocess, 47.8ms inference, 17.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-57-134.png: 416x640 3 persons, 2 cars, 1 traffic light, 65.0ms
# Speed: 0.0ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-57-167.png: 416x640 3 persons, 2 cars, 1 traffic light, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-57-234.png: 416x640 3 persons, 3 cars, 1 traffic light, 66.5ms
# Speed: 0.0ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-57-367.png: 416x640 1 person, 2 cars, 1 traffic light, 66.5ms
# Speed: 0.0ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-57-434.png: 416x640 2 cars, 1 traffic light, 64.4ms
# Speed: 0.0ms preprocess, 64.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-57-534.png: 416x640 2 persons, 2 cars, 1 traffic light, 62.6ms
# Speed: 15.6ms preprocess, 62.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-57-634.png: 416x640 2 persons, 1 car, 1 traffic light, 66.2ms
# Speed: 0.0ms preprocess, 66.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-57-667.png: 416x640 1 person, 1 car, 1 traffic light, 65.0ms
# Speed: 0.0ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-57-934.png: 416x640 2 persons, 1 bus, 1 traffic light, 62.5ms
# Speed: 2.9ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-57-967.png: 416x640 2 persons, 1 bus, 1 traffic light, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-58-034.png: 416x640 2 persons, 1 bus, 1 truck, 1 traffic light, 66.0ms
# Speed: 0.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-58-234.png: 416x640 2 persons, 1 bus, 1 truck, 1 traffic light, 64.6ms
# Speed: 0.0ms preprocess, 64.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-58-267.png: 416x640 2 persons, 1 bus, 1 traffic light, 63.1ms
# Speed: 0.0ms preprocess, 63.1ms inference, 17.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-58-334.png: 416x640 2 persons, 1 traffic light, 66.5ms
# Speed: 0.0ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-58-534.png: 416x640 2 persons, 1 car, 1 traffic light, 64.5ms
# Speed: 0.0ms preprocess, 64.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-58-634.png: 416x640 2 persons, 1 truck, 1 traffic light, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-58-834.png: 416x640 1 person, 1 truck, 1 traffic light, 67.3ms
# Speed: 0.0ms preprocess, 67.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-58-867.png: 416x640 1 person, 1 truck, 1 traffic light, 66.0ms
# Speed: 0.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-58-934.png: 416x640 1 person, 1 truck, 1 traffic light, 61.0ms
# Speed: 0.0ms preprocess, 61.0ms inference, 15.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-59-034.png: 416x640 1 person, 1 traffic light, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 15.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-59-067.png: 416x640 1 person, 1 car, 1 traffic light, 50.4ms
# Speed: 15.7ms preprocess, 50.4ms inference, 15.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-59-134.png: 416x640 1 person, 2 cars, 1 traffic light, 64.6ms
# Speed: 0.0ms preprocess, 64.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-59-167.png: 416x640 1 person, 1 car, 1 train, 1 traffic light, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-59-234.png: 416x640 1 person, 1 train, 1 traffic light, 66.9ms
# Speed: 0.0ms preprocess, 66.9ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-59-367.png: 416x640 1 person, 1 traffic light, 65.1ms
# Speed: 0.0ms preprocess, 65.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-59-534.png: 416x640 1 person, 2 cars, 1 traffic light, 62.4ms
# Speed: 0.0ms preprocess, 62.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-59-634.png: 416x640 1 person, 1 car, 1 traffic light, 67.2ms
# Speed: 0.0ms preprocess, 67.2ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-59-734.png: 416x640 1 person, 1 traffic light, 52.2ms
# Speed: 1.3ms preprocess, 52.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-35-59-934.png: 416x640 1 person, 2 cars, 1 traffic light, 64.2ms
# Speed: 0.0ms preprocess, 64.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-00-034.png: 416x640 1 person, 4 cars, 1 traffic light, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-00-234.png: 416x640 1 person, 2 cars, 1 traffic light, 51.6ms
# Speed: 0.4ms preprocess, 51.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-00-534.png: 416x640 1 person, 1 traffic light, 64.8ms
# Speed: 0.0ms preprocess, 64.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-00-634.png: 416x640 1 person, 1 car, 1 traffic light, 63.6ms
# Speed: 0.0ms preprocess, 63.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-00-834.png: 416x640 1 person, 1 traffic light, 83.6ms
# Speed: 0.0ms preprocess, 83.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-00-867.png: 416x640 1 person, 1 traffic light, 64.5ms
# Speed: 0.0ms preprocess, 64.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-00-934.png: 416x640 1 person, 1 traffic light, 73.6ms
# Speed: 0.0ms preprocess, 73.6ms inference, 5.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-01-167.png: 416x640 1 person, 1 traffic light, 63.1ms
# Speed: 0.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-01-234.png: 416x640 1 person, 1 traffic light, 64.0ms
# Speed: 0.0ms preprocess, 64.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-01-334.png: 416x640 1 person, 1 traffic light, 76.7ms
# Speed: 0.0ms preprocess, 76.7ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-01-367.png: 416x640 1 person, 1 traffic light, 64.3ms
# Speed: 0.0ms preprocess, 64.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-01-434.png: 416x640 1 person, 1 traffic light, 52.7ms
# Speed: 14.4ms preprocess, 52.7ms inference, 13.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-01-467.png: 416x640 1 person, 1 traffic light, 66.8ms
# Speed: 0.0ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-01-534.png: 416x640 1 person, 1 traffic light, 65.1ms
# Speed: 2.0ms preprocess, 65.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-01-634.png: 416x640 1 person, 1 traffic light, 68.0ms
# Speed: 13.8ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-01-734.png: 416x640 1 person, 1 traffic light, 66.7ms
# Speed: 15.5ms preprocess, 66.7ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-02-034.png: 416x640 1 person, 1 traffic light, 52.1ms
# Speed: 13.6ms preprocess, 52.1ms inference, 14.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-02-334.png: 416x640 1 person, 1 traffic light, 63.2ms
# Speed: 0.0ms preprocess, 63.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-02-534.png: 416x640 1 person, 1 traffic light, 63.8ms
# Speed: 0.0ms preprocess, 63.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-02-567.png: 416x640 1 person, 1 traffic light, 64.3ms
# Speed: 0.0ms preprocess, 64.3ms inference, 16.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-02-634.png: 416x640 1 person, 1 traffic light, 64.4ms
# Speed: 0.0ms preprocess, 64.4ms inference, 16.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-02-834.png: 416x640 1 person, 1 truck, 1 traffic light, 63.2ms
# Speed: 0.0ms preprocess, 63.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-03-134.png: 416x640 1 person, 1 car, 1 traffic light, 68.2ms
# Speed: 0.0ms preprocess, 68.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-03-334.png: 416x640 1 person, 1 traffic light, 64.2ms
# Speed: 0.0ms preprocess, 64.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-03-367.png: 416x640 1 person, 1 truck, 1 traffic light, 63.2ms
# Speed: 2.7ms preprocess, 63.2ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-03-534.png: 416x640 1 person, 1 traffic light, 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-03-634.png: 416x640 1 person, 1 traffic light, 49.7ms
# Speed: 0.6ms preprocess, 49.7ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-03-667.png: 416x640 1 person, 1 traffic light, 74.8ms
# Speed: 0.0ms preprocess, 74.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-03-934.png: 416x640 1 person, 1 traffic light, 63.9ms
# Speed: 0.0ms preprocess, 63.9ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-03-967.png: 416x640 1 person, 1 traffic light, 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-04-034.png: 416x640 1 person, 1 traffic light, 99.1ms
# Speed: 0.0ms preprocess, 99.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-04-234.png: 416x640 1 person, 1 traffic light, 64.1ms
# Speed: 0.0ms preprocess, 64.1ms inference, 16.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-04-267.png: 416x640 1 person, 1 traffic light, 68.0ms
# Speed: 16.1ms preprocess, 68.0ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-04-534.png: 416x640 1 person, 1 traffic light, 64.6ms
# Speed: 0.0ms preprocess, 64.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-04-634.png: 416x640 1 person, 1 traffic light, 64.6ms
# Speed: 0.0ms preprocess, 64.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-04-834.png: 416x640 1 person, 1 traffic light, 64.5ms
# Speed: 0.0ms preprocess, 64.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-04-934.png: 416x640 1 person, 1 traffic light, 65.7ms
# Speed: 0.8ms preprocess, 65.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-05-067.png: 416x640 1 person, 1 traffic light, 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-05-134.png: 416x640 1 person, 1 traffic light, 63.1ms
# Speed: 0.0ms preprocess, 63.1ms inference, 15.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-05-367.png: 416x640 1 person, 1 traffic light, 65.9ms
# Speed: 0.6ms preprocess, 65.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-05-434.png: 416x640 1 person, 1 traffic light, 66.4ms
# Speed: 0.0ms preprocess, 66.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-05-467.png: 416x640 1 person, 1 traffic light, 69.5ms
# Speed: 0.0ms preprocess, 69.5ms inference, 13.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-05-667.png: 416x640 1 person, 1 traffic light, 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-05-834.png: 416x640 1 person, 1 traffic light, 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-05-967.png: 416x640 1 person, 1 traffic light, 66.5ms
# Speed: 0.0ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-06-234.png: 416x640 1 person, 1 traffic light, 66.4ms
# Speed: 12.0ms preprocess, 66.4ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-06-267.png: 416x640 1 person, 1 traffic light, 67.4ms
# Speed: 0.0ms preprocess, 67.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-06-334.png: 416x640 1 person, 1 traffic light, 47.9ms
# Speed: 19.1ms preprocess, 47.9ms inference, 20.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-06-534.png: 416x640 1 person, 1 traffic light, 70.3ms
# Speed: 0.0ms preprocess, 70.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-06-634.png: 416x640 1 person, 1 car, 1 traffic light, 73.4ms
# Speed: 0.0ms preprocess, 73.4ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-06-834.png: 416x640 1 person, 1 car, 1 traffic light, 50.2ms
# Speed: 16.5ms preprocess, 50.2ms inference, 18.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-06-867.png: 416x640 1 person, 1 car, 1 traffic light, 66.8ms
# Speed: 0.0ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-06-934.png: 416x640 1 person, 1 car, 1 traffic light, 68.3ms
# Speed: 16.6ms preprocess, 68.3ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-07-167.png: 416x640 1 person, 1 traffic light, 62.2ms
# Speed: 4.0ms preprocess, 62.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-07-367.png: 416x640 1 person, 1 traffic light, 66.8ms
# Speed: 0.0ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-07-434.png: 416x640 1 person, 1 traffic light, 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-07-467.png: 416x640 1 person, 1 traffic light, 67.8ms
# Speed: 0.0ms preprocess, 67.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-07-534.png: 416x640 1 person, 1 traffic light, 64.5ms
# Speed: 0.0ms preprocess, 64.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-07-767.png: 416x640 1 person, 1 traffic light, 63.2ms
# Speed: 2.0ms preprocess, 63.2ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-07-834.png: 416x640 1 person, 1 traffic light, 58.9ms
# Speed: 2.0ms preprocess, 58.9ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-07-967.png: 416x640 1 person, 1 traffic light, 66.3ms
# Speed: 0.0ms preprocess, 66.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-08-034.png: 416x640 1 person, 1 traffic light, 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-08-234.png: 416x640 1 person, 1 traffic light, 65.0ms
# Speed: 10.9ms preprocess, 65.0ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-08-267.png: 416x640 1 person, 1 traffic light, 69.0ms
# Speed: 0.0ms preprocess, 69.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-08-334.png: 416x640 1 person, 1 traffic light, 77.0ms
# Speed: 0.0ms preprocess, 77.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-08-367.png: 416x640 1 person, 1 traffic light, 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 16.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-08-534.png: 416x640 1 person, 1 traffic light, 73.4ms
# Speed: 0.0ms preprocess, 73.4ms inference, 8.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-08-567.png: 416x640 1 person, 1 traffic light, 64.0ms
# Speed: 4.5ms preprocess, 64.0ms inference, 5.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-08-634.png: 416x640 1 person, 1 traffic light, 70.3ms
# Speed: 0.0ms preprocess, 70.3ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-08-934.png: 416x640 1 person, 1 car, 1 traffic light, 68.7ms
# Speed: 0.0ms preprocess, 68.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-08-967.png: 416x640 1 person, 1 car, 1 traffic light, 64.0ms
# Speed: 5.7ms preprocess, 64.0ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-09-134.png: 416x640 1 person, 1 car, 1 traffic light, 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-09-234.png: 416x640 1 person, 1 car, 1 traffic light, 65.1ms
# Speed: 9.8ms preprocess, 65.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-09-367.png: 416x640 1 person, 1 car, 1 traffic light, 64.7ms
# Speed: 3.2ms preprocess, 64.7ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-09-434.png: 416x640 1 person, 1 traffic light, 150.2ms
# Speed: 0.0ms preprocess, 150.2ms inference, 8.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-09-467.png: 416x640 1 person, 1 traffic light, 76.7ms
# Speed: 0.0ms preprocess, 76.7ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-09-534.png: 416x640 1 person, 1 traffic light, 69.9ms
# Speed: 0.0ms preprocess, 69.9ms inference, 7.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-09-667.png: 416x640 1 person, 1 traffic light, 66.4ms
# Speed: 0.0ms preprocess, 66.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-09-734.png: 416x640 1 person, 1 car, 1 traffic light, 59.9ms
# Speed: 10.1ms preprocess, 59.9ms inference, 5.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-09-767.png: 416x640 1 person, 1 car, 1 traffic light, 58.8ms
# Speed: 5.1ms preprocess, 58.8ms inference, 6.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-09-834.png: 416x640 1 person, 1 car, 1 traffic light, 62.6ms
# Speed: 2.1ms preprocess, 62.6ms inference, 3.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-09-934.png: 416x640 1 person, 1 traffic light, 60.2ms
# Speed: 6.1ms preprocess, 60.2ms inference, 5.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-09-967.png: 416x640 1 person, 1 traffic light, 69.4ms
# Speed: 0.0ms preprocess, 69.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-10-034.png: 416x640 1 person, 1 traffic light, 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-10-067.png: 416x640 1 person, 1 traffic light, 68.6ms
# Speed: 0.0ms preprocess, 68.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-10-134.png: 416x640 1 person, 1 traffic light, 66.4ms
# Speed: 0.0ms preprocess, 66.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-10-234.png: 416x640 1 person, 1 car, 1 traffic light, 63.0ms
# Speed: 0.0ms preprocess, 63.0ms inference, 16.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-10-267.png: 416x640 1 person, 1 traffic light, 66.5ms
# Speed: 0.0ms preprocess, 66.5ms inference, 13.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-10-334.png: 416x640 1 person, 1 traffic light, 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 16.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-10-534.png: 416x640 1 person, 1 car, 1 traffic light, 66.4ms
# Speed: 0.0ms preprocess, 66.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-10-567.png: 416x640 1 person, 1 car, 1 traffic light, 83.1ms
# Speed: 0.0ms preprocess, 83.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-10-634.png: 416x640 1 person, 1 car, 1 traffic light, 78.8ms
# Speed: 0.0ms preprocess, 78.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-10-834.png: 416x640 1 person, 1 car, 1 traffic light, 71.0ms
# Speed: 0.0ms preprocess, 71.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-10-934.png: 416x640 1 person, 1 car, 1 traffic light, 62.6ms
# Speed: 4.0ms preprocess, 62.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-11-134.png: 416x640 1 person, 1 traffic light, 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-11-167.png: 416x640 1 person, 1 car, 1 traffic light, 65.0ms
# Speed: 16.4ms preprocess, 65.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-11-234.png: 416x640 1 person, 1 car, 1 traffic light, 68.2ms
# Speed: 0.0ms preprocess, 68.2ms inference, 12.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-11-367.png: 416x640 1 person, 1 car, 1 traffic light, 66.6ms
# Speed: 14.3ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-11-534.png: 416x640 1 person, 1 traffic light, 68.8ms
# Speed: 0.0ms preprocess, 68.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-11-734.png: 416x640 1 person, 1 car, 1 bus, 1 traffic light, 53.0ms
# Speed: 14.0ms preprocess, 53.0ms inference, 13.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-11-767.png: 416x640 1 person, 1 bus, 1 traffic light, 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-11-834.png: 416x640 1 person, 1 traffic light, 66.8ms
# Speed: 14.3ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-11-934.png: 416x640 1 person, 1 traffic light, 66.5ms
# Speed: 0.5ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-12-034.png: 416x640 1 person, 1 truck, 1 traffic light, 66.7ms
# Speed: 0.5ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-12-134.png: 416x640 1 person, 1 train, 1 traffic light, 69.5ms
# Speed: 0.0ms preprocess, 69.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-12-234.png: 416x640 1 person, 1 car, 1 traffic light, 66.7ms
# Speed: 14.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-12-267.png: 416x640 1 person, 1 car, 1 traffic light, 60.6ms
# Speed: 0.0ms preprocess, 60.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-12-334.png: 416x640 1 person, 1 car, 1 traffic light, 65.3ms
# Speed: 0.6ms preprocess, 65.3ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-12-534.png: 416x640 1 person, 1 bus, 1 traffic light, 83.2ms
# Speed: 0.0ms preprocess, 83.2ms inference, 15.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-12-567.png: 416x640 1 person, 1 bus, 1 traffic light, 83.3ms
# Speed: 0.0ms preprocess, 83.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-12-634.png: 416x640 1 person, 1 bus, 1 traffic light, 66.5ms
# Speed: 9.6ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-12-834.png: 416x640 1 person, 1 bus, 1 traffic light, 69.6ms
# Speed: 0.0ms preprocess, 69.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-12-867.png: 416x640 1 person, 1 traffic light, 67.0ms
# Speed: 0.0ms preprocess, 67.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Dk\Projects\Team Project\YOLO detection\Test 1\Camera Data\camera_01__2023-07-06-19-36-12-934.png: 416x640 1 person, 1 traffic light, 63.5ms
# Speed: 0.0ms preprocess, 63.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 90
#      87 cv2.destroyAllWindows()
#      89 # Calculate the mean IoU score
# ---> 90 mean_iou = np.mean(iou_scores)
#      92 print(f"The mean IoU score is {mean_iou}")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\core\fromnumeric.py:3504, in mean(a, axis, dtype, out, keepdims, where)
#    3501     else:
#    3502         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3504 return _methods._mean(a, axis=axis, dtype=dtype,
#    3505                       out=out, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\core\_methods.py:102, in _mean(a, axis, dtype, out, keepdims, where)
#     101 def _mean(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
# --> 102     arr = asanyarray(a)
#     104     is_float16_result = False
#     106     rcount = _count_reduce_items(arr, axis, keepdims=keepdims, where=where)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\_tensor.py:1062, in Tensor.__array__(self, dtype)
#    1060     return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#    1061 if dtype is None:
# -> 1062     return self.numpy()
#    1063 else:
#    1064     return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
print(results)
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[254, 255, 254],
#         [254, 255, 254],
#         [255, 255, 255],
#         ...,
#         [254, 255, 254],
#         [254, 255, 254],
#         [254, 255, 254]],
#
#        [[254, 255, 254],
#         [254, 255, 254],
#         [255, 255, 255],
#         ...,
#         [254, 255, 254],
#         [254, 255, 254],
#         [254, 255, 254]],
#
#        [[254, 255, 254],
#         [254, 255, 254],
#         [255, 255, 255],
#         ...,
#         [254, 255, 254],
#         [254, 255, 254],
#         [254, 255, 254]],
#
#        ...,
#
#        [[ 21,  23,  18],
#         [ 21,  26,  17],
#         [ 24,  25,  19],
#         ...,
#         [ 50,  38,  30],
#         [ 56,  42,  30],
#         [ 59,  42,  30]],
#
#        [[ 20,  25,  18],
#         [ 20,  25,  18],
#         [ 23,  24,  19],
#         ...,
#         [ 48,  38,  26],
#         [ 51,  40,  26],
#         [ 51,  43,  25]],
#
#        [[ 20,  25,  18],
#         [ 20,  25,  18],
#         [ 21,  24,  19],
#         ...,
#         [ 48,  38,  26],
#         [ 47,  40,  26],
#         [ 47,  43,  25]]], dtype=uint8)
# orig_shape: (1216, 1920)
# path: 'C:\\Dk\\Projects\\Team Project\\YOLO detection\\Test 1\\Camera Data\\camera_01__2023-07-06-19-35-52-934.png'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 1.001119613647461, 'inference': 813.9266967773438, 'postprocess': 0.0}]
